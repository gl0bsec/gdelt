# %% [markdown]
# # Detailed breakdown of regional conflict in the Gulf: 12/12/2023 - 90/12/2023

# %%
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')
# import viz
filtered_df = pd.read_json('gdelt_mea1.json')

# %%
import modified_analysis_working as aw
aw.visualize_top_fncact_tones_by_top_countries(filtered_df,25,10)
