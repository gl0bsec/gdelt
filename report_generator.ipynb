# %%
import pandas as pd 
# import viz
filtered_df = pd.read_json('gdelt_ISR.json')

# %% [markdown]
# # Online news coverage leading up to and following the Israel-Hamas conflict: A 30 day timeline

# %% [markdown]
# ### Tone and frequency analysis

# %%
import modified_analysis_working as aw
# Call the function with the DataFrame and a specified date to test it
aw.plot_from_dataframe(filtered_df, '20231007')

# %% [markdown]
# ### Themes and Organizations

# %%
# Creating DataFrames for positive and negative tone countries, ordered by count
excluded_themes = ['TAX_FNCACT', " "]
aw.generate_visualizations2(filtered_df, 'Israel', 30, excluded_themes)
# Out:
# /home/cromwell/Desktop/Projects/SPIR/gdelt/modified_analysis_working.py:100: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot_themes_reversed = sns.barplot(x=theme_counts_n, y=theme_names_n, palette=theme_colors_reversed, ax=axes[0])
# /home/cromwell/Desktop/Projects/SPIR/gdelt/modified_analysis_working.py:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot_orgs_reversed = sns.barplot(x=org_counts_n, y=org_names_n, palette=org_colors_reversed, ax=axes[1])

# %%
import corrected_locations as loc
positive_df, negative_df = aw.create_organization_tone_dataframes_ordered_by_count(filtered_df, top_n=30)# Example filter list
aw.plot_side_by_side_organization_tones(positive_df,negative_df)

# %% [markdown]
# ### Location analytics

# %%
# Plotting the bar charts for the top countries with negative and positive tones, shaded by average tone
loc.plot_country_tones(filtered_df, location_column='LOCATIONS', tone_column='TONE')
# Out:
# /home/cromwell/Desktop/Projects/SPIR/gdelt/locations.py:51: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
loc.plot_country_frequencies(filtered_df, location_column='LOCATIONS', contrast_scale=0.4)
# Out:
# /home/cromwell/Desktop/Projects/SPIR/gdelt/locations.py:83: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
positive_df, negative_df = loc.create_tone_dataframes_ordered_by_count(filtered_df)
loc.plot_side_by_side_tone_locations(negative_df, positive_df)

# %% [markdown]
# ### Sources

# %%
# Creating a DataFrame for sources
sources_df = aw.create_source_tone_dataframes_ordered_by_count(filtered_df)
# Plotting the bar chart for the top sources, shaded by average tone
aw.plot_source_counts_shaded_by_tone(sources_df,50)
